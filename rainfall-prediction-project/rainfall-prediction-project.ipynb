# %% [markdown]
# # Rainfall Prediction

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("austin_weather.csv")
data
# Out:
#             Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0     2013-12-21         74        60        45            67           49
# 1     2013-12-22         56        48        39            43           36
# 2     2013-12-23         58        45        32            31           27
# 3     2013-12-24         61        46        31            36           28
# 4     2013-12-25         58        50        41            44           40
# ...          ...        ...       ...       ...           ...          ...
# 1314  2017-07-27        103        89        75            71           67
# 1315  2017-07-28        105        91        76            71           64
# 1316  2017-07-29        107        92        77            72           64
# 1317  2017-07-30        106        93        79            70           68
# 1318  2017-07-31         99        88        77            66           61
#
# ...

# %%
data.head()
# Out:
#          Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0  2013-12-21         74        60        45            67           49
# 1  2013-12-22         56        48        39            43           36
# 2  2013-12-23         58        45        32            31           27
# 3  2013-12-24         61        46        31            36           28
# 4  2013-12-25         58        50        41            44           40
#
#   DewPointLowF HumidityHighPercent HumidityAvgPercent HumidityLowPercent  ...  \
# 0           43                  93                 75                 57  ...
# 1           28                  93                 68                 43  ...
# 2           23                  76                 52                 27  ...
# 3           21                  89                 56                 22  ...
# 4           36                  86                 71                 56  ...
#
# ...

# %%
# drop useless column
data = data.drop(["Events","Date","SeaLevelPressureLowInches"] ,axis=1 )

# %%
data = data.replace('T',0.0)

# %%
data = data.replace('-',0.0)

# %%
data
# Out:
#       TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF DewPointLowF  \
# 0            74        60        45            67           49           43
# 1            56        48        39            43           36           28
# 2            58        45        32            31           27           23
# 3            61        46        31            36           28           21
# 4            58        50        41            44           40           36
# ...         ...       ...       ...           ...          ...          ...
# 1314        103        89        75            71           67           61
# 1315        105        91        76            71           64           55
# 1316        107        92        77            72           64           55
# 1317        106        93        79            70           68           63
# 1318         99        88        77            66           61           54
#
# ...

# %%
data.to_csv("austin_weather_final.csv")

# %%
# importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as sk
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv("austin_weather_final.csv")
data
# Out:
#       Unnamed: 0  TempHighF  TempAvgF  TempLowF  DewPointHighF  DewPointAvgF  \
# 0              0         74        60        45           67.0          49.0
# 1              1         56        48        39           43.0          36.0
# 2              2         58        45        32           31.0          27.0
# 3              3         61        46        31           36.0          28.0
# 4              4         58        50        41           44.0          40.0
# ...          ...        ...       ...       ...            ...           ...
# 1314        1314        103        89        75           71.0          67.0
# 1315        1315        105        91        76           71.0          64.0
# 1316        1316        107        92        77           72.0          64.0
# 1317        1317        106        93        79           70.0          68.0
# 1318        1318         99        88        77           66.0          61.0
#
# ...

# %%
x = data.drop(["PrecipitationSumInches"],axis = 1)

# %%
y = data["PrecipitationSumInches"]

# %%
#reshaping it into 2d vector
y=y.values.reshape(-1,1)

# %%
y
# Out:
# array([[0.46],
#        [0.  ],
#        [0.  ],
#        ...,
#        [0.  ],
#        [0.  ],
#        [0.  ]], shape=(1319, 1))

# %%
day_index = 798
days = [i for i in range(y. size)]

# %%
# initialize the regressin classifier
clf = LinearRegression()

clf.fit(x,y)
# Out:
# LinearRegression()

# %%
# plot the graph
print("The precipitation graph:")
plt.scatter(days,y,color = 'g')
plt.scatter(days[day_index], y[day_index], color = 'r')
plt.title("precipitation level")
plt.xlabel("days")
plt.ylabel("precipitation in inches")
plt.show()
x_vis = x.filter(["TempAvgf","DewPointAvgF","HumidityAvgPercent","SeaLevelPressureAvgInches","VisibilityAvgMiles","WindAvgMPH"])
# Out:
# The precipitation graph:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math

# Example data — replace this with your real data
np.random.seed(0)
days = np.arange(1, 11)  # days 1–10
x_vis = pd.DataFrame({
    "Feature1": np.random.rand(10),
    "Feature2": np.random.rand(10),
    "Feature3": np.random.rand(10),
    "Feature4": np.random.rand(10),
    "Feature5": np.random.rand(10),
    "Feature6": np.random.rand(10),
    "Feature7": np.random.rand(10),
    "Feature8": np.random.rand(10)
})
day_index = 5  # highlight the 6th day

# Determine subplot grid size automatically
n_cols = 2  # you can change this if you want more columns in the grid
n_rows = math.ceil(len(x_vis.columns) / n_cols)

# Create subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(10, n_rows * 3))
axes = axes.flatten()  # make it a 1D array for easy indexing

# Plot each feature
for i, col in enumerate(x_vis.columns):
    axes[i].scatter(days, x_vis[col], color='g')  # all days
    axes[i].scatter(days[day_index], x_vis[col].iloc[day_index], color='r')  # highlight
    axes[i].set_title(col)

# Remove any unused subplots
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()
